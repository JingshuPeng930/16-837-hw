# %% [markdown]
# ##Setup
#
# You will need to make a copy of this notebook in your Google Drive before you can edit the homework files. You can do so with **File &rarr; Save a copy in Drive**. Please run on GPU: Runtime -> Change runtime type -> Set Runtime version to 2025.07 -> Hardware accelerator -> T4 GPU

# %%
#@title mount your Google Drive
#@markdown Your work will be stored in a folder called `hw_16831` by default to prevent Colab instance timeouts from deleting your edits.

import os
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#@title set up mount symlink

DRIVE_PATH = r'/content/gdrive/My\ Drive/hw_16831'
DRIVE_PYTHON_PATH = DRIVE_PATH.replace('\\', '')
if not os.path.exists(DRIVE_PYTHON_PATH):
  # %mkdir $DRIVE_PATH

## the space in `My Drive` causes some issues,
## make a symlink to avoid this
SYM_PATH = '/content/hw_16831'
if not os.path.exists(SYM_PATH):
  # !ln -s $DRIVE_PATH $SYM_PATH

# %%
#@title apt install requirements

#@markdown Run each section with Shift+Enter

#@markdown Double-click on section headers to show code.

# !apt update
# !apt install -y --no-install-recommends \
        build-essential \
        curl \
        git \
        gnupg2 \
        make \
        cmake \
        ffmpeg \
        swig \
        libz-dev \
        unzip \
        zlib1g-dev \
        libglfw3 \
        libglfw3-dev \
        libxrandr2 \
        libxinerama-dev \
        libxi6 \
        libxcursor-dev \
        libgl1-mesa-dev \
        libgl1-mesa-glx \
        libglew-dev \
        libosmesa6-dev \
        lsb-release \
        ack-grep \
        patchelf \
        wget \
        xpra \
        xserver-xorg-dev \
        xvfb \
        python3-opengl \
        ffmpeg
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [4,685 B]
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 4,685 B in 1s (3,522 B/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 70 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'zlib1g-dev' instead of 'libz-dev'
# Note, selecting 'ack' instead of 'ack-grep'
# build-essential is already the newest version (12.9ubuntu3).
# libxcursor-dev is already the newest version (1:1.2.0-2build4).
# libxi6 is already the newest version (2:1.8-1build1).
# libxinerama-dev is already the newest version (2:1.1.4-3).
# libxrandr2 is already the newest version (2:1.5.2-1build1).
# lsb-release is already the newest version (11.1.0ubuntu4).
# make is already the newest version (4.3-4.1build1).
# ack is already the newest version (3.5.0-1).
# libglew-dev is already the newest version (2.2.0-4).
# libglfw3 is already the newest version (3.3.6-1).
# libglfw3-dev is already the newest version (3.3.6-1).
# patchelf is already the newest version (0.14.3-1).
# python3-opengl is already the newest version (3.1.5+dfsg-1).
# swig is already the newest version (4.0.2-1ubuntu1).
# xpra is already the newest version (3.1-1build5).
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# curl is already the newest version (7.81.0-1ubuntu1.27).
# git is already the newest version (1:2.34.1-1ubuntu1.17).
# libgl1-mesa-dev is already the newest version (23.2.1-1ubuntu3.1~22.04.4).
# libosmesa6-dev is already the newest version (23.2.1-1ubuntu3.1~22.04.4).
# unzip is already the newest version (6.0-26ubuntu3.2).
# wget is already the newest version (1.21.2-2ubuntu1.5).
# xserver-xorg-dev is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-2ubuntu9.2).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# gnupg2 is already the newest version (2.2.27-3ubuntu2.5).
# libgl1-mesa-glx is already the newest version (23.0.4-0ubuntu1~22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# 0 upgraded, 0 newly installed, 0 to remove and 70 not upgraded.

# %%
#@title clone homework repo

# if free-mujoco-py version error appears, run next two cells

# %cd $SYM_PATH
# !git clone https://github.com/LeCAR-Lab/16831-F26-HW.git
# %cd 16831-F26-HW/hw1
# %pip install -r requirements.txt
# %pip install -e .
# Out:
# /content/gdrive/My Drive/hw_16831
# fatal: destination path '16831-F26-HW' already exists and is not an empty directory.
# /content/gdrive/My Drive/hw_16831/16831-F26-HW/hw1
# Collecting numpy==1.25.2 (from -r requirements.txt (line 1))
#   Using cached numpy-1.25.2.tar.gz (10.8 MB)
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Obtaining file:///content/gdrive/MyDrive/hw_16831/16831-F26-HW/hw1
#   Preparing metadata (setup.py) ... done
# Installing collected packages: rob831
#   Attempting uninstall: rob831
#     Found existing installation: rob831 0.1.0
#     Uninstalling rob831-0.1.0:
#       Successfully uninstalled rob831-0.1.0
#   Running setup.py develop for rob831
# Successfully installed rob831-0.1.0

# %%
# downloads mujoco from source
# !wget https://mujoco.org/download/mujoco210-linux-x86_64.tar.gz
# !tar xzvf mujoco210-linux-x86_64.tar.gz
# !mkdir -p ~/.mujoco
# !mv mujoco210 ~/.mujoco/mujoco210
# !rm mujoco*

# %pip install -U mujoco
# %pip install -U 'mujoco-py<2.2,>=2.1'
# %pip install -U pyvirtualdisplay
# %pip install -U gym-notebook-wrapper
# %pip install -U "cython<3"

# !cp /root/.mujoco/mujoco210/bin/*.so /usr/lib/x86_64-linux-gnu/
# Out:
# --2026-09-02 03:00:06--  https://mujoco.org/download/mujoco210-linux-x86_64.tar.gz
# Resolving mujoco.org (mujoco.org)... 216.239.36.21, 216.239.34.21, 216.239.38.21, ...
# Connecting to mujoco.org (mujoco.org)|216.239.36.21|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/google-deepmind/mujoco/releases/download/2.1.0/mujoco210-linux-x86_64.tar.gz [following]
# --2026-09-02 03:00:07--  https://github.com/google-deepmind/mujoco/releases/download/2.1.0/mujoco210-linux-x86_64.tar.gz
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/400501136/1f51148e-4e64-4a12-a400-d6f1e21be444?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-09-02T03%3A55%3A15Z&rscd=attachment%3B+filename%3Dmujoco210-linux-x86_64.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-09-02T02%3A54%3A37Z&ske=2026-09-02T03%3A55%3A15Z&sks=b&skv=2018-11-09&sig=OT824TVIgQ6SRBlYLXDE4JcQqwc03jJvR9Vs8Xc7X%2Bk%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4ODMxODMwNywibmJmIjoxNzg4MzE4MDA3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.ird-hXWlia_6AYxEnFHYBMBkBnVKUzpe-Zhsesfp7FA&response-content-disposition=attachment%3B%20filename%3Dmujoco210-linux-x86_64.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2026-09-02 03:00:07--  https://release-assets.githubusercontent.com/github-production-release-asset/400501136/1f51148e-4e64-4a12-a400-d6f1e21be444?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-09-02T03%3A55%3A15Z&rscd=attachment%3B+filename%3Dmujoco210-linux-x86_64.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-09-02T02%3A54%3A37Z&ske=2026-09-02T03%3A55%3A15Z&sks=b&skv=2018-11-09&sig=OT824TVIgQ6SRBlYLXDE4JcQqwc03jJvR9Vs8Xc7X%2Bk%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4ODMxODMwNywibmJmIjoxNzg4MzE4MDA3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.ird-hXWlia_6AYxEnFHYBMBkBnVKUzpe-Zhsesfp7FA&response-content-disposition=attachment%3B%20filename%3Dmujoco210-linux-x86_64.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4385135 (4.2M) [application/octet-stream]
# Saving to: ‘mujoco210-linux-x86_64.tar.gz’
#
# mujoco210-linux-x86 100%[===================>]   4.18M  --.-KB/s    in 0.1s
#
# 2026-09-02 03:00:07 (29.8 MB/s) - ‘mujoco210-linux-x86_64.tar.gz’ saved [4385135/4385135]
#
# mujoco210/
# mujoco210/THIRD_PARTY_NOTICES
# mujoco210/bin/
# mujoco210/bin/libglfw.so.3
# mujoco210/bin/derivative
# mujoco210/bin/libglew.so
# mujoco210/bin/record
# mujoco210/bin/simulate
# mujoco210/bin/libglewegl.so
# mujoco210/bin/testxml
# mujoco210/bin/basic
# mujoco210/bin/libglewosmesa.so
# mujoco210/bin/libglfw3.a
# mujoco210/bin/libmujoco210.so
# mujoco210/bin/compile
# mujoco210/bin/libmujoco210nogl.so
# mujoco210/bin/testspeed
# mujoco210/include/
# mujoco210/include/glfw3.h
# mujoco210/include/uitools.c
# mujoco210/include/mjxmacro.h
# mujoco210/include/mjui.h
# mujoco210/include/mjrender.h
# mujoco210/include/mjmodel.h
# mujoco210/include/mjdata.h
# mujoco210/include/mujoco.h
# mujoco210/include/mjvisualize.h
# mujoco210/include/uitools.h
# mujoco210/model/
# mujoco210/model/humanoid100.xml
# mujoco210/model/arm26.xml
# mujoco210/model/carpet.png
# mujoco210/model/softbox.xml
# mujoco210/model/grid2pin.xml
# mujoco210/model/sponge.png
# mujoco210/model/hammock.xml
# mujoco210/model/cloth.xml
# mujoco210/model/grid2.xml
# mujoco210/model/grid1.xml
# mujoco210/model/grid1pin.xml
# mujoco210/model/softellipsoid.xml
# mujoco210/model/softcylinder.xml
# mujoco210/model/marble.png
# mujoco210/model/rope.xml
# mujoco210/model/particle.xml
# mujoco210/model/loop.xml
# mujoco210/model/humanoid.xml
# mujoco210/model/scene.xml
# mujoco210/sample/
# mujoco210/sample/derivative.cc
# mujoco210/sample/testspeed.cc
# mujoco210/sample/Makefile
# mujoco210/sample/basic.cc
# mujoco210/sample/record.cc
# mujoco210/sample/compile.cc
# mujoco210/sample/simulate.cc
# mujoco210/sample/testxml.cc
# Requirement already satisfied: mujoco in /usr/local/lib/python3.13/dist-packages (3.12.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.13/dist-packages (from mujoco) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.13/dist-packages (from mujoco) (1.14.0)
# Requirement already satisfied: glfw in /usr/local/lib/python3.13/dist-packages (from mujoco) (2.10.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from mujoco) (2.1.3)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.13/dist-packages (from mujoco) (3.1.10)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.13/dist-packages (from etils[epath]->mujoco) (2025.3.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.13/dist-packages (from etils[epath]->mujoco) (4.16.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.13/dist-packages (from etils[epath]->mujoco) (4.1.0)
# Requirement already satisfied: mujoco-py<2.2,>=2.1 in /usr/local/lib/python3.13/dist-packages (2.1.2.14)
# Requirement already satisfied: glfw>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from mujoco-py<2.2,>=2.1) (2.10.2)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.13/dist-packages (from mujoco-py<2.2,>=2.1) (2.1.3)
# Requirement already satisfied: Cython>=0.27.2 in /usr/local/lib/python3.13/dist-packages (from mujoco-py<2.2,>=2.1) (0.29.37)
# Requirement already satisfied: imageio>=2.1.2 in /usr/local/lib/python3.13/dist-packages (from mujoco-py<2.2,>=2.1) (2.37.4)
# Requirement already satisfied: cffi>=1.10 in /usr/local/lib/python3.13/dist-packages (from mujoco-py<2.2,>=2.1) (2.1.1)
# Requirement already satisfied: fasteners~=0.15 in /usr/local/lib/python3.13/dist-packages (from mujoco-py<2.2,>=2.1) (0.20)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=1.10->mujoco-py<2.2,>=2.1) (3.0)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.13/dist-packages (from imageio>=2.1.2->mujoco-py<2.2,>=2.1) (11.3.0)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.13/dist-packages (3.0)
# Requirement already satisfied: gym-notebook-wrapper in /usr/local/lib/python3.13/dist-packages (1.3.3)
# Requirement already satisfied: gym in /usr/local/lib/python3.13/dist-packages (from gym-notebook-wrapper) (0.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from gym-notebook-wrapper) (3.10.0)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.13/dist-packages (from gym-notebook-wrapper) (3.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.13/dist-packages (from gym-notebook-wrapper) (7.34.0)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.13/dist-packages (from gym-notebook-wrapper) (1.0.3)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.13/dist-packages (from gym->gym-notebook-wrapper) (2.1.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from gym->gym-notebook-wrapper) (3.1.2)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.13/dist-packages (from gym->gym-notebook-wrapper) (0.1.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.13/dist-packages (from ipython->gym-notebook-wrapper) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.13/dist-packages (from ipython->gym-notebook-wrapper) (0.20.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.13/dist-packages (from ipython->gym-notebook-wrapper) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.13/dist-packages (from ipython->gym-notebook-wrapper) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.13/dist-packages (from ipython->gym-notebook-wrapper) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from ipython->gym-notebook-wrapper) (3.0.53)
# Requirement already satisfied: pygments in /usr/local/lib/python3.13/dist-packages (from ipython->gym-notebook-wrapper) (2.21.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.13/dist-packages (from ipython->gym-notebook-wrapper) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.13/dist-packages (from ipython->gym-notebook-wrapper) (0.2.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.13/dist-packages (from ipython->gym-notebook-wrapper) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->gym-notebook-wrapper) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib->gym-notebook-wrapper) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->gym-notebook-wrapper) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->gym-notebook-wrapper) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->gym-notebook-wrapper) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib->gym-notebook-wrapper) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->gym-notebook-wrapper) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib->gym-notebook-wrapper) (2.9.0.post0)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.13/dist-packages (from moviepy->gym-notebook-wrapper) (4.67.3)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.13/dist-packages (from moviepy->gym-notebook-wrapper) (2.32.4)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.13/dist-packages (from moviepy->gym-notebook-wrapper) (0.1.12)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.13/dist-packages (from moviepy->gym-notebook-wrapper) (2.37.4)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from moviepy->gym-notebook-wrapper) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.13/dist-packages (from jedi>=0.16->ipython->gym-notebook-wrapper) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.13/dist-packages (from pexpect>4.3->ipython->gym-notebook-wrapper) (0.7.0)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.13/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->gym-notebook-wrapper) (0.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib->gym-notebook-wrapper) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0,>=2.8.1->moviepy->gym-notebook-wrapper) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests<3.0,>=2.8.1->moviepy->gym-notebook-wrapper) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3.0,>=2.8.1->moviepy->gym-notebook-wrapper) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests<3.0,>=2.8.1->moviepy->gym-notebook-wrapper) (2026.7.22)
# Requirement already satisfied: cython<3 in /usr/local/lib/python3.13/dist-packages (0.29.37)

# %% [markdown]
# In order to run tensorboardX, a new version of protobuf will need to be re-installed. After running the command below, you will need to restart the runtime. After re-starting the runtime, please run the first and second code snippets to re-mount Google Drive. You do not need to re-install python packages or system apt-get packages. These will be maintained.

# %%
# %pip install tensorboardX
# %pip uninstall -y protobuf
# After installing new version of protobuf, you need to restart the runtime
# Then run the first and second code snippets to re-mount Google Drive
# %pip install protobuf==3.20.3
# Out:
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.13/dist-packages (2.6.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from tensorboardX) (2.1.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from tensorboardX) (26.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.13/dist-packages (from tensorboardX) (3.20.3)
# Found existing installation: protobuf 3.20.3
# Uninstalling protobuf-3.20.3:
#   Successfully uninstalled protobuf-3.20.3
# Collecting protobuf==3.20.3
#   Using cached protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Using cached protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
# Installing collected packages: protobuf
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.21.0 requires protobuf>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# google-cloud-bigquery-storage 2.39.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# wandb 0.28.1 requires protobuf!=5.28.0,!=5.29.0,<8,>=5, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-spanner 3.68.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-datastore 2.25.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-firestore 2.27.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-language 2.21.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-functions 1.24.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# grain 0.2.18 requires protobuf>=5.28.3, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-bigquery-connection 1.22.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-monitoring 2.31.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-resource-manager 1.18.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-api-core 2.30.3 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# googleapis-common-protos 1.75.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-dataproc 5.28.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# grpc-google-iam-v1 0.14.4 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# tensorflow 2.20.0 requires protobuf>=5.28.0, but you have protobuf 3.20.3 which is incompatible.
# proto-plus 1.28.2 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-translate 3.27.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# Successfully installed protobuf-3.20.3

# %%
# After re-installing protobuf and restarting the runtime, resume here
# set env variables
import os
os.environ['LD_LIBRARY_PATH'] = os.environ.get('LD_LIBRARY_PATH', '') + ':/root/.mujoco/mujoco210/bin'
# os.environ['LD_LIBRARY_PATH'] += ':/root/.mujoco/mujoco210/bin'
os.environ['MUJOCO_PY_MUJOCO_PATH'] = '/root/.mujoco/mujoco210'
os.environ['LD_LIBRARY_PATH'] += ':/usr/lib/nvidia'
os.environ['PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION'] = 'python'

# %%
#@title set up virtual display

from pyvirtualdisplay import Display

display = Display(visible=0, size=(1400, 900))
display.start()

# %%
#@title test virtual display

#@markdown If you see a video of a four-legged ant fumbling about, setup is complete!

import gym
import gnwrapper

env = gnwrapper.LoopAnimation(gym.make('Ant-v2'))

observation = env.reset()
for i in range(100):
    obs, rew, term, _ = env.step(env.action_space.sample())
    env.render()
    if term:
      break

env.display()
env.close()

# %% [markdown]
# ## Editing Code
#
# To edit code, click the folder icon on the left menu. Navigate to the corresponding file (`hw_16831/...`). Double click a file to open an editor. There is a timeout of about ~12 hours with Colab while it is active (and less if you close your browser window). We sync your edits to Google Drive so that you won't lose your work in the event of an instance timeout, but you will need to re-mount your Google Drive and re-install packages with every new instance.

# %% [markdown]
# ## Run Behavior Cloning (Problem 1)

# %%
#@title imports

import os
import time
import numpy as np

from rob831.infrastructure.rl_trainer import RL_Trainer
from rob831.agents.bc_agent import BCAgent
from rob831.policies.loaded_gaussian_policy import LoadedGaussianPolicy

# %load_ext autoreload
# %autoreload 2

# %%
#@title runtime arguments

class Args:

  def __getitem__(self, key):
    return getattr(self, key)

  def __setitem__(self, key, val):
    setattr(self, key, val)

  #@markdown expert data
  expert_policy_file = 'rob831/policies/experts/Ant.pkl' #@param
  expert_data = 'rob831/expert_data/expert_data_Ant-v2.pkl' #@param
  env_name = 'Ant-v2' #@param ['Ant-v2', 'Humanoid-v2', 'Walker2d-v2', 'HalfCheetah-v2', 'Hopper-v2']
  exp_name = 'test_bc_ant' #@param
  do_dagger = False #@param {type: "boolean"}
  ep_len = 1000 #@param {type: "integer"}
  save_params = False #@param {type: "boolean"}

  num_agent_train_steps_per_iter = 1000 #@param {type: "integer"})
  n_iter = 1 #@param {type: "integer"})

  #@markdown batches & buffers
  batch_size = 1000 #@param {type: "integer"})
  eval_batch_size = 1000 #@param {type: "integer"}
  train_batch_size = 100 #@param {type: "integer"}
  max_replay_buffer_size = 1000000 #@param {type: "integer"}

  #@markdown network
  n_layers = 2 #@param {type: "integer"}
  size = 64 #@param {type: "integer"}
  learning_rate = 5e-3 #@param {type: "number"}

  #@markdown logging
  video_log_freq = 5 #@param {type: "integer"}
  scalar_log_freq = 1 #@param {type: "integer"}

  #@markdown gpu & run-time settings
  no_gpu = False #@param {type: "boolean"}
  which_gpu = 0 #@param {type: "integer"}
  seed = 1 #@param {type: "integer"}

args = Args()

# %%
#@title define `BC_Trainer`
class BC_Trainer(object):

    def __init__(self, params):
        #######################
        ## AGENT PARAMS
        #######################

        agent_params = {
            'n_layers': params['n_layers'],
            'size': params['size'],
            'learning_rate': params['learning_rate'],
            'max_replay_buffer_size': params['max_replay_buffer_size'],
            }

        self.params = params
        self.params['agent_class'] = BCAgent ## TODO: look in here and implement this
        self.params['agent_params'] = agent_params

        ################
        ## RL TRAINER
        ################

        self.rl_trainer = RL_Trainer(self.params) ## TODO: look in here and implement this

        #######################
        ## LOAD EXPERT POLICY
        #######################

        print('Loading expert policy from...', self.params['expert_policy_file'])
        self.loaded_expert_policy = LoadedGaussianPolicy(self.params['expert_policy_file'])
        print('Done restoring expert policy...')

    def run_training_loop(self):

        self.rl_trainer.run_training_loop(
            n_iter=self.params['n_iter'],
            initial_expertdata=self.params['expert_data'],
            collect_policy=self.rl_trainer.agent.actor,
            eval_policy=self.rl_trainer.agent.actor,
            relabel_with_expert=self.params['do_dagger'],
            expert_policy=self.loaded_expert_policy,
        )

# %%
#@title create directory for logging

if args.do_dagger:
    logdir_prefix = 'q2_'
    assert args.n_iter>1, ('DAgger needs more than 1 iteration (n_iter>1) of training, to iteratively query the expert and train (after 1st warmstarting from behavior cloning).')
else:
    logdir_prefix = 'q1_'
    assert args.n_iter==1, ('Vanilla behavior cloning collects expert data just once (n_iter=1)')

data_path ='/content/hw_16831/hw1/data'
if not (os.path.exists(data_path)):
    os.makedirs(data_path)
logdir = logdir_prefix + args.exp_name + '_' + args.env_name + \
         '_' + time.strftime("%d-%m-%Y_%H-%M-%S")
logdir = os.path.join(data_path, logdir)
args['logdir'] = logdir
if not(os.path.exists(logdir)):
    os.makedirs(logdir)

# %%
# Make sure you're in the 16831-F26-HW/hw1 folder when running this.
# Uncomment the following line to check your current directory
# %pwd
# You may need to modify this to the correct directory
# %cd hw_16831/hw1
## run training
print(args.logdir)
trainer = BC_Trainer(args)
trainer.run_training_loop()

# %%
#@markdown You can visualize your runs with tensorboard from within the notebook

# %load_ext tensorboard
# %tensorboard --logdir /content/hw_16831/hw1/data

# %% [markdown]
# ## Running DAgger (Problem 2)
# Modify the settings above:
# 1. check the `do_dagger` box
# 2. set `n_iters` to `10`
# and then rerun the code.
